# %% [markdown]
# # infranettone-kind

# %% [markdown]
# ## Tabla de contenidos
#
# - [Prerrequisitos](#Prerrequisitos)
#     - [Instalar extension Jupyter a secas en VSCode](#Instalar-extension-Jupyter-a-secas-en-VSCode)
#     - [Instalar dependencias](#Instalar-dependencias)

# %% [markdown]
# ## Prerrequisitos

# %% [markdown]
# ### Instalar extension Jupyter a secas en VSCode

# %% [markdown]
# ### Instalar dependencias

# %%
python3 -m venv .venv
source .venv/bin/activate
which python
pip install --upgrade pip
pip install jupyter bash_kernel
python -m bash_kernel.install
jupyter kernelspec list
jupyter notebook

# %% [markdown]
# ### Configurar variables de este Jupyter Notebook

# %%
# Variables sensibles, no las subas al repo git
export BASTION_PEM_PASSWORD="CAMBIAME_Y_NO_LA_SUBAS_AL_REPO_GIT"
echo BASTION_PEM_PASSWORD=BASTION_PEM_PASSWORD
# Out:
# BASTION_PEM_PASSWORD=BASTION_PEM_PASSWORD

# %%
# Variables de AWS



# Variables de SSH
# Out:
# AWS_PROFILE=homedelivery
# AWS_REGION=eu-west-1
# AWS_DUMP_MACHINE_INSTANCE_ID=i-0e208d3f45920af61
# BASTION_USER=radamuz
# BASTION_HOST=52.17.102.144
# BASTION_PEM_FILE=/tmp/tmp.Zvn69enkWI
# DUMP_MACHINE_HOST=10.106.71.12
# DUMP_MACHINE_USER=admin

# %% [markdown]
# ## Instalar Kind con BREW

# %%
brew install kind

# %% [markdown]
# ## Crear Cluster con BREW

# %%
kind create cluster
# Out:
# Creating cluster "kind" ...
#  ✓ Ensuring node image (kindest/node:v1.36.1) 🖼7l
#  ✓ Preparing nodes 📦 7l
#  ✓ Writing configuration 📜
#  ✓ Starting control-plane 🕹️7l
#  ✓ Installing CNI 🔌7l
#  ✓ Installing StorageClass 💾7l
# Set kubectl context to "kind-kind"
# You can now use your cluster with:
#
# kubectl cluster-info --context kind-kind
#
# Not sure what to do next? 😅  Check out https://kind.sigs.k8s.io/docs/user/quick-start/

# %% [markdown]
# ## Usar Cluster

# %%
kubectl cluster-info --context kind-kind
# Out:
# Kubernetes control plane is running at https://127.0.0.1:45355
# CoreDNS is running at https://127.0.0.1:45355/api/v1/namespaces/kube-system/services/kube-dns:dns/proxy
#
# To further debug and diagnose cluster problems, use 'kubectl cluster-info dump'.

# %% [markdown]
# ## TODO: Levantar NetBox en KIND: https://artifacthub.io/packages/helm/netbox/netbox
